# %% [markdown]
# <a href="https://colab.research.google.com/github/Mahathirrr/app-ideas/blob/master/belajar_google_collab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Hello World!')
# Out:
# Hello World!

# %% [markdown]
# # Contoh

# %%
for i in range(5):
  print("index:", i)
# Out:
# index: 0
# index: 1
# index: 2
# index: 3
# index: 4

# %%
# !pip install numpy

# %%
# !python --version
# Out:
# Python 3.10.12

# %%
# !pip list
# Out:
# Package                          Version
# -------------------------------- ---------------------
# absl-py                          1.4.0
# accelerate                       0.32.1
# aiohappyeyeballs                 2.3.5
# aiohttp                          3.10.3
# aiosignal                        1.3.1
# alabaster                        0.7.16
# albucore                         0.0.13
# albumentations                   1.4.13
# altair                           4.2.2
# annotated-types                  0.7.0
# anyio                            3.7.1
# argon2-cffi                      23.1.0
# argon2-cffi-bindings             21.2.0
# array_record                     0.5.1
# arviz                            0.18.0
# asn1crypto                       1.5.1
# astropy                          6.1.2
# astropy-iers-data                0.2024.8.12.0.32.58
# astunparse                       1.6.3
# async-timeout                    4.0.3
# atpublic                         4.1.0
# ...

# %%
# !sudo apt-get update -y
# !sudo apt-get install python3.7
# Out:
# Get:1 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Ign:4 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Get:5 https://r2u.stat.illinois.edu/ubuntu jammy Release [5,713 B]
# Get:6 https://r2u.stat.illinois.edu/ubuntu jammy Release.gpg [793 B]
# Hit:7 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:9 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,135 kB]
# Get:10 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [2,175 kB]
# Get:11 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,555 kB]
# Get:12 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [2,871 kB]
# ...

# %%
# !sudo update-alternatives --install /usr/bin/python3 python3 /usr/bin/python3.7 1
# Out:
# update-alternatives: using /usr/bin/python3.7 to provide /usr/bin/python3 (python3) in auto mode

# %%
# !python3 --version
# Out:
# Python 3.7.17
